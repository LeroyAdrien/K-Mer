# %% [markdown]
# #  GENOM PROJECT 2020-2021
#
# ## Kmer computation in Horizontal transfert origin prediction
# #### Alex Lence, Simon Chardin, Adrien Leroy
#
# This project is the **second** part of the project and shows how we predicted the origin of Kmer signature from horizontal transfers from K-Mer signatures using **kython** and a hard coded Fully connected neural network.
#
# [Kython on Github](https://www.github.com/LeroyAdrien/Kython), [Kython on testPypi](https://test.pypi.org/project/kython/)

# %% [markdown]
# <img src='TOL_notebook.png' title="Tree from Archaeas and Bacterias">&nbsp;

# %% [markdown]
# ##### This notebook shows:
#
# * **Module pp**
#     * Preparing Data for the training of the neural network
#
# * **Module pl**

# %%
from kython import pp,pl
import matplotlib.pyplot as plt
import numpy as np
import random
from scipy.stats import chi2_contingency
from os import listdir
from os.path import isfile, join
import pandas as pd
import random as rd

# %% [markdown]
# ### I-Retrieving organisms names linked to their .fna files
#
# We used a nested dictionnary to be able to retrieve phylums, organism names and genomin .fna file path
#
#
#
# **Structure is the following:** $\color{black}{\text{Dictionnary}}$**\[**$\color{blue}{\text{Phylum}}$**\]\[**$\color{blue}{\text{Organism}}$**\]=**$\color{red}{\text{'Path to Genomic File'}}$
#
# #### Setting up paths

# %%
bacteriaListPath='../data/Bacteria.list'
archaeaListPath='../data/Archea.list'
resultsfolder='./refseq/'

# %%
pathDictionnary=pp.ParseSequences(resultsfolder)

# %% [markdown]
# #### We retreived the following organisms:

# %%
print("Bacterias:",'\n')
for bacteria in pathDictionnary['bacteria'].keys():
    print(bacteria)
print("\n")

print("Archaeas:",'\n')
for archaea in pathDictionnary['archaea'].keys():
    print(archaea)
# Out:
# Bacterias:
#
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a
# Methylacidiphilum_infernorum_V4
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_66322_
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8558_chromosome_CBM2615_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3679_
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_ip2.30/pp_2.30_chromosome_CBM2623_a
# Coxiella_burnetii_RSA_493
# Campylobacter_jejuni_subsp._jejuni_81-176-UMCW7_plasmid_pVir
# Mycoplasma_genitalium_G37
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3521_chromosome_CBM2589_a
# Bacteroides_fragilis_YCH46
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3511_chromosome_CBM2588_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8561_chromosome_CBM2618_a
# Thermotoga_maritima_MSB8
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_mpp_1.3_chromosome_CBM2625_a
# Nostoc_punctiforme_PCC_73102
# Bordetella_pertussis_Tohama_I_
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6150_chromosome_CBM2608_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6132_chromosome_CBM2599_a
# Gemmata_obscuriglobus_UQM_2246_
# Thermanaerovibrio_acidaminovorans_DSM_6589
# Gloeobacter_violaceus_PCC_7421
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6043_chromosome_CBM2597_a
# Shewanella_putrefaciens_CN-32
# Gemmatimonas_aurantiaca_T-27
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3681
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_65033_
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8556_chromosome_CBM2613_a
# Clostridium_acetobutylicum_ATCC_824
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3711_chromosome_CBM2592_a
# Campylobacter_jejuni_subsp._jejuni_81-176
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8557_chromosome_CBM2614_a
# Corynebacterium_glutamicum_ATCC_13032
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_cmp_52
# Chlorobium_chlorochromatii_CaD3
# Mycoplasma_genitalium_G37_strain_G-37_unique_20
# Prochlorococcus_marinus_str._AS9601
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_MAPUD_10.1
# Deinococcus_radiodurans_R1_chromosome_1
# Rhizobium_leguminosarum_bv._trifolii_WSM1325
# Pedobacter_heparinus_DSM_2366_ctg7180000000005_quiver
# Bacillus_cereus_Q1
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6021_chromosome_CBM2594_a
# Thermomicrobium_roseum_DSM_5159
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6162_chromosome_CBM2600_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_66324_chromosome_CBM2637_a
# Akkermansia_muciniphila_ATCC_BAA-835
# Cupriavidus_taiwanensis_isolate_Cupriavidus_sp._LMG_19464_chromosome_CBM2587_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8564_chromosome_CBM2621_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_TPUD_27.6_chromosome_CBM2631_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8560_chromosome_CBM2617_a
# Leptospira_interrogans_serovar_Lai_str._56601_chromosome_I
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_TPIG_6a_chromosome_CBM2629_a
# Gemmata_obscuriglobus_UQM_2246_gcontig_1106221710807
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6082_chromosome_CBM2605_a
# Carboxydothermus_hydrogenoformans_Z-2901
# Bordetella_pertussis_Tohama_I
# Flavobacterium_psychrophilum_JIP02/86
# Bdellovibrio_bacteriovorus_HD100
# Coxiella_burnetii_RSA_493_strain_Cb171_QLYMPHOMA
# Alicyclobacillus_acidocaldarius_subsp._acidocaldarius_DSM_446
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8565_chromosome_CBM2622_a
# Fibrobacter_succinogenes_subsp._succinogenes_S85
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19431_chromosome_CT19431
# Rickettsia_rickettsii_str._Iowa
# Rhodospirillum_rubrum_ATCC_11170
# Bacteroides_fragilis_YCH46_isolate_Bacteroides_fragilis_82A12
# Synechococcus_elongatus_PCC_6301
# Thermobaculum_terrenum_ATCC_BAA-798_chromosome_1
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6044_
# Candidatus_Amoebophilus_asiaticus_5a2
# Aquifex_aeolicus_VF5
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_mpp_1.1_chromosome_CBM2626_a
# Dictyoglomus_thermophilum_H-6-12
# Opitutus_terrae_PB90-1
# Cupriavidus_taiwanensis_STM_6018_A3AADRAFT_scaffold_0.1_C
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6117_chromosome_CBM2604_a
# Cupriavidus_taiwanensis_LMG_19424
# Elusimicrobium_minutum_Pei191
# Cupriavidus_taiwanensis_strain_USM6_USM6_assembled_contig_1
# Acholeplasma_laidlawii_PG-8A
# Psychrobacter_arcticus_273-4
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19430_chromosome_CBM2586_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19426_chromosome_CBM2585_a
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6041_plasmid_I
# Thermodesulfovibrio_yellowstonii_DSM_11347
# Chlamydia_trachomatis_434/Bu
# Rhodopirellula_baltica_SH_1
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19425_
# Thermus_thermophilus_HB8_chromosome_1
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6083_
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6032_
# Bacillus_pseudofirmus_OF4
# Pirellula_staleyi_DSM_6068
# Acidobacterium_capsulatum_ATCC_51196
# Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6116_chromosome_CBM2609_a
# Chloroflexus_aurantiacus_J-10-fl
# Pedobacter_heparinus_DSM_2366
#
#
# Archaeas:
#
# Picrophilus_torridus_DSM_9790
# Methanobrevibacter_ruminantium_M1
# Candidatus_Korarchaeum_cryptofilum_OPF8
# Metallosphaera_sedula_DSM_5348
# Ignicoccus_hospitalis_KIN4/I
# Nitrosopumilus_maritimus_SCM1
# Methanosphaera_stadtmanae_DSM_3091
# Methanocaldococcus_fervens_AG86
# Pyrobaculum_aerophilum_str._IM2
# Methanospirillum_hungatei_JF-1
# Pyrobaculum_arsenaticum_DSM_13514
# Methanosarcina_acetivorans_C2A
# Pyrococcus_abyssi_GE5
# Pyrococcus_furiosus_DSM_3638
# Halorubrum_lacusprofundi_ATCC_49239_chromosome_1
# Methanosarcina_barkeri_str._Fusaro
# Archaeoglobus_profundus_DSM_5631
# Methanococcoides_burtonii_DSM_6242
# Halomicrobium_mukohataei_DSM_12286
# Natronomonas_pharaonis_DSM_2160
# Sulfolobus_acidocaldarius_DSM_639
# Methanocorpusculum_labreanum_Z
# Hyperthermus_butylicus_DSM_5456
# Aeropyrum_pernix_K1
# Thermofilum_pendens_Hrk_5
# Haloquadratum_walsbyi_DSM_16790
# Caldivirga_maquilingensis_IC-167
# Halorhabdus_utahensis_DSM_12940
# Staphylothermus_marinus_F1
# Thermoplasma_acidophilum_DSM_1728
# Archaeoglobus_fulgidus_DSM_4304
# Haloarcula_marismortui_ATCC_43049_chromosome_I
# Haloarcula_marismortui_ATCC_43049
# Methanococcus_aeolicus_Nankai-3
# Pyrococcus_horikoshii_OT3
# Methanococcus_vannielii_SB
# Methanosarcina_mazei_Go1
# Thermococcus_gammatolerans_EJ3
# Methanocella_paludicola_SANAE
# Methanopyrus_kandleri_AV19
# Methanococcus_maripaludis_C6
# Haloterrigena_turkmenica_DSM_5511
# Thermoplasma_volcanium_GSS1
# Methanoculleus_marisnigri_JR1

# %% [markdown]
# ### II-Building the Neural network

# %% [markdown]
# #### a-Classes

# %%
class Layer:
    def __init__(self):
        self.input = None
        self.output = None
        
    def forward_propagation(self,input):
        raise NotImplementedError
        
    def backward_propagation(self,output_error, learning_rate):
        raise NotImplementedError

# inherit from base class Layer
class FCLayer(Layer):
    # input_size = number of input neurons
    # output_size = number of output neurons
    def __init__(self, input_size, output_size):
        self.weights = np.random.rand(input_size, output_size) - 0.5
        self.bias = np.random.rand(1, output_size) - 0.5

    # returns output for a given input
    def forward_propagation(self, input_data):
        self.input = input_data
        self.output = np.dot(self.input, self.weights) + self.bias
        return self.output

    # computes dE/dW, dE/dB for a given output_error=dE/dY. Returns input_error=dE/dX.
    def backward_propagation(self, output_error, learning_rate):
        input_error = np.dot(output_error, self.weights.T)
        weights_error = np.dot(self.input.T, output_error)
        # dBias = output_error

        # update parameters
        self.weights -= learning_rate * weights_error
        self.bias -= learning_rate * output_error
        return input_error

    
# inherit from base class Layer
class ActivationLayer(Layer):
    def __init__(self, activation, activation_prime):
        self.activation = activation
        self.activation_prime = activation_prime

    # returns the activated input
    def forward_propagation(self, input_data):
        self.input = input_data
        self.output = self.activation(self.input)
        return self.output

    # Returns input_error=dE/dX for a given output_error=dE/dY.
    # learning_rate is not used because there is no "learnable" parameters.
    def backward_propagation(self, output_error, learning_rate):
        return self.activation_prime(self.input) * output_error
    
    

class Network:
    def __init__(self):
        self.layers = []
        self.loss = None
        self.loss_prime = None

    # add layer to network
    def add(self, layer):
        self.layers.append(layer)

    # set loss to use
    def use(self, loss, loss_prime):
        self.loss = loss
        self.loss_prime = loss_prime

    # predict output for given input
    def predict(self, input_data):
        # sample dimension first
        samples = len(input_data)
        result = []

        # run network over all samples
        for i in range(samples):
            # forward propagation
            output = input_data[i]
            for layer in self.layers:
                output = layer.forward_propagation(output)
            result.append(output)

        return result

    # train the network
    def fit(self, x_train, y_train, epochs, learning_rate):
        # sample dimension first
        samples = len(x_train)

        # training loop
        for i in range(epochs):
            err = 0
            for j in range(samples):
                # forward propagation
                output = x_train[j]
                for layer in self.layers:
                    output = layer.forward_propagation(output)

                # compute loss (for display purpose only)
                err += self.loss(y_train[j], output)

                # backward propagation
                error = self.loss_prime(y_train[j], output)
                for layer in reversed(self.layers):
                    error = layer.backward_propagation(error, learning_rate)

            # calculate average error on all samples
            err /= samples
            #print('epoch %d/%d   error=%f' % (i+1, epochs, err))

# loss function and its derivative
def mse(y_true, y_pred):
    return np.mean(np.power(y_true-y_pred, 2));

def mse_prime(y_true, y_pred):
    return 2*(y_pred-y_true)/y_true.size;
            
# activation function and its derivative
def tanh(x):
    return np.tanh(x);

def tanh_prime(x):
    return 1-np.tanh(x)**2;

# %% [markdown]
# #### b-Functions

# %%
def def_matrice_learn(supermatrice):
    "Initialization of learning's matrix and label from the GatherTrainingData file"
    Y_learn=[]
    X_learn=[]
    for i in range(len(supermatrice)):
        if len(supermatrice[i])>=50:
            for j in range(50):
                y_learn=np.zeros(len(supermatrice))
                y_learn[i]=1
                Y_learn.append(y_learn)
                X_learn.append([supermatrice[i][j]])
        else:
            for j in range(len(supermatrice[i])):
                y_learn=np.zeros(len(supermatrice))
                y_learn[i]=1
                Y_learn.append(y_learn)
                X_learn.append([supermatrice[i][j]])
                
    return(np.array(X_learn),np.array(Y_learn))
 

def nom_organisme(inputPath):
    "Creat list of species and the supermatrix that concatenate all the kmer signature "
    supermatrice=[]
    liste_org=[]
    fichiers = [f for f in listdir(inputPath) if isfile(join(inputPath, f))]
    for org in fichiers:
        try:
            data=pd.read_csv(inputPath+"/"+org)
            org=org.split("_")[1]
            org=org.split(".")[0]
            liste_org.append(org)
            supermatrice.append(data.values)
        #If a file is empty
        except ValueError:
            pass
    return(liste_org,np.array(supermatrice))

def FindOrganism(kmer: int, kmersignature:list, inputPath:str,train=True)->str:
    liste_org,supermatrice=nom_organisme(inputPath)
    X_learn,Y_learn=def_matrice_learn(supermatrice)
    
    # Network
    net = Network()
    net.add(FCLayer(4**kmer, 300))                # input_shape=(1, 4**kmer)    ;   output_shape=(1, 300)
    net.add(ActivationLayer(tanh, tanh_prime))
    net.add(FCLayer(300, 200))                   # input_shape=(1, 300)      ;   output_shape=(1, 200)
    net.add(ActivationLayer(tanh, tanh_prime))
    net.add(FCLayer(200, 128))                   # input_shape=(1, 200)      ;   output_shape=(1, 128)
    net.add(ActivationLayer(tanh, tanh_prime))
    net.add(FCLayer(128,len(liste_org)))          # input_shape=(1, 128)      ;   output_shape=(1, len(liste_org))         
    net.add(ActivationLayer(tanh, tanh_prime))

    
    #Function use for forward and backward activation 
    net.use(mse, mse_prime)
    
    #Shuffle the learning matrix and the label matrix as the same
    rd.seed(0)
    rd.shuffle(X_learn)
    rd.seed(0)
    rd.shuffle(Y_learn)
    
    
    #Fit the network on the data from GatherTrainingData file
    if train==True:
        net.fit(X_learn, Y_learn, epochs=10, learning_rate=0.1)

    #Predict the species from kmersignature
    out = net.predict(kmersignature)
    print(liste_org[np.argmax(out)])
    return(liste_org[np.argmax(out)])

# %% [markdown]
# ### III-Application : Organism of interest

# %%
print("Bacteria: Coxiella burnetii RSA 493")

signature=pp.KmerSignature(pathDictionnary["bacteria"]["Coxiella_burnetii_RSA_493"],3,False)
pl.KmerSignature(signature,"Coxiella burnetii RSA 493")

listPvalue,listPositions=pp.SequenceHomogeneity(pathDictionnary["bacteria"]["Coxiella_burnetii_RSA_493"],6,10000)
pl.SequenceHomogeneity(listPvalue,listPositions,0.05,"Coxiella burnetii RSA 493")
# Out:
# Bacteria: Coxiella burnetii RSA 493

# %% [markdown]
# ### IV- Apllying the network on a given organism

# %% [markdown]
# #### Preparing Data <u> (about 45 minutes Long on i5 7200 U and 6Gb RAM)

# %%
pp.GatherTrainingData(pathDictionnary,3,20000,'../data/training_data',0.05,'bacteria')
# Out:
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a
# Number of Samples Gathered: 0
# Size of file: 96
# Gathering Training Data from:  Methylacidiphilum_infernorum_V4
# Number of Samples Gathered: 1
# Size of file: 624
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_66322_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8558_chromosome_CBM2615_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3679_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_ip2.30/pp_2.30_chromosome_CBM2623_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Coxiella_burnetii_RSA_493
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Campylobacter_jejuni_subsp._jejuni_81-176-UMCW7_plasmid_pVir
# Number of Samples Gathered: 30
# Size of file: 15472
# Gathering Training Data from:  Mycoplasma_genitalium_G37
# Number of Samples Gathered: 26
# Size of file: 13424
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3521_chromosome_CBM2589_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bacteroides_fragilis_YCH46
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3511_chromosome_CBM2588_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8561_chromosome_CBM2618_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermotoga_maritima_MSB8
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_mpp_1.3_chromosome_CBM2625_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Nostoc_punctiforme_PCC_73102
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bordetella_pertussis_Tohama_I_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6150_chromosome_CBM2608_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6132_chromosome_CBM2599_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Gemmata_obscuriglobus_UQM_2246_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermanaerovibrio_acidaminovorans_DSM_6589
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Gloeobacter_violaceus_PCC_7421
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6043_chromosome_CBM2597_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Shewanella_putrefaciens_CN-32
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Gemmatimonas_aurantiaca_T-27
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3681
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_65033_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8556_chromosome_CBM2613_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Clostridium_acetobutylicum_ATCC_824
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_3711_chromosome_CBM2592_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Campylobacter_jejuni_subsp._jejuni_81-176
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8557_chromosome_CBM2614_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Corynebacterium_glutamicum_ATCC_13032
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_cmp_52
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Chlorobium_chlorochromatii_CaD3
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Mycoplasma_genitalium_G37_strain_G-37_unique_20
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Prochlorococcus_marinus_str._AS9601
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_MAPUD_10.1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Deinococcus_radiodurans_R1_chromosome_1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Rhizobium_leguminosarum_bv._trifolii_WSM1325
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Pedobacter_heparinus_DSM_2366_ctg7180000000005_quiver
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bacillus_cereus_Q1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6021_chromosome_CBM2594_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermomicrobium_roseum_DSM_5159
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6162_chromosome_CBM2600_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_SWF_66324_chromosome_CBM2637_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Akkermansia_muciniphila_ATCC_BAA-835
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_sp._LMG_19464_chromosome_CBM2587_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8564_chromosome_CBM2621_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_TPUD_27.6_chromosome_CBM2631_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8560_chromosome_CBM2617_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Leptospira_interrogans_serovar_Lai_str._56601_chromosome_I
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_TPIG_6a_chromosome_CBM2629_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Gemmata_obscuriglobus_UQM_2246_gcontig_1106221710807
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6082_chromosome_CBM2605_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Carboxydothermus_hydrogenoformans_Z-2901
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bordetella_pertussis_Tohama_I
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Flavobacterium_psychrophilum_JIP02/86
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bdellovibrio_bacteriovorus_HD100
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Coxiella_burnetii_RSA_493_strain_Cb171_QLYMPHOMA
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Alicyclobacillus_acidocaldarius_subsp._acidocaldarius_DSM_446
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_8565_chromosome_CBM2622_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Fibrobacter_succinogenes_subsp._succinogenes_S85
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19431_chromosome_CT19431
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Rickettsia_rickettsii_str._Iowa
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Rhodospirillum_rubrum_ATCC_11170
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bacteroides_fragilis_YCH46_isolate_Bacteroides_fragilis_82A12
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Synechococcus_elongatus_PCC_6301
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermobaculum_terrenum_ATCC_BAA-798_chromosome_1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6044_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Candidatus_Amoebophilus_asiaticus_5a2
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Aquifex_aeolicus_VF5
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_mpp_1.1_chromosome_CBM2626_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Dictyoglomus_thermophilum_H-6-12
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Opitutus_terrae_PB90-1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_STM_6018_A3AADRAFT_scaffold_0.1_C
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6117_chromosome_CBM2604_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_LMG_19424
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Elusimicrobium_minutum_Pei191
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_strain_USM6_USM6_assembled_contig_1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Acholeplasma_laidlawii_PG-8A
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Psychrobacter_arcticus_273-4
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19430_chromosome_CBM2586_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19426_chromosome_CBM2585_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6041_plasmid_I
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermodesulfovibrio_yellowstonii_DSM_11347
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Chlamydia_trachomatis_434/Bu
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Rhodopirellula_baltica_SH_1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_LMG_19425_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Thermus_thermophilus_HB8_chromosome_1
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6083_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6032_
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Bacillus_pseudofirmus_OF4
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Pirellula_staleyi_DSM_6068
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Acidobacterium_capsulatum_ATCC_51196
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6116_chromosome_CBM2609_a
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Chloroflexus_aurantiacus_J-10-fl
# Number of Samples Gathered: 51
# Size of file: 26224
# Gathering Training Data from:  Pedobacter_heparinus_DSM_2366
# Number of Samples Gathered: 51
# Size of file: 26224

# %% [markdown]
# #### Training the Network

# %%
def FindHorizontalTransfers(path:str,kmer:int,fragmentSize:int,seuil:float):
        """Compute the Homogeneity of a sequence and spots any horizontal transfers """
        #Retrieve sequence and dictionnary
        globalSignature=pp.KmerSignature(path,kmer,False)
        sequence=pp.Read_Sequence(path)
        
        #List of values
        listepval = []
        listepos= [0]
        listOrigins=[]
        pos=0
        train=True
        
        while pos<len(sequence):
                """
                if int(pos/len(sequence)*100)%5==0:
                        print((pos/len(sequence))*100,"%")
                """
                #Cuts sequence fragment
                sequenceFragment=sequence[pos:pos+fragmentSize]
                seqCut = [sequenceFragment[i:i+kmer] for i in range(len(sequenceFragment)-(kmer-1)) ]
                
                #Retrieve signature of fragment
                fragmentSignature = pp.Count_Cuts(seqCut,False)
                
                #Create contingency table
                contingency=np.concatenate((globalSignature.values+1,fragmentSignature.values+1),axis=0)
                
                
                resultat,pval, dof, expctd = chi2_contingency(contingency)
                
                if pval<seuil:
                    organismFound=FindOrganism(kmer,list(fragmentSignature.values),'../data/training_data',train)
                    train=False
                    listOrigins.append(organismFound)
                    


                if pos+fragmentSize>len(sequence):
                        fragmentSize=len(sequence)-pos
                        pos+=fragmentSize
                else:
                        pos+=fragmentSize
                        
                #Add new position
                listepos.append(pos)

        return listepval,listepos,listOrigins

# %%
listepVal,listepos,listOrigins=FindHorizontalTransfers(pathDictionnary["bacteria"]["Coxiella_burnetii_RSA_493"],3,10000,0.05)
# Out:
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# <ipython-input-6-fe7c6a25600c>:37: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(liste_org,np.array(supermatrice))
# Bacillus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Candidatus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bordetella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rickettsia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Mycoplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rickettsia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gloeobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bacillus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Deinococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pedobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pedobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Psychrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhodospirillum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Opitutus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Deinococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhizobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Carboxydothermus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chlamydia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Deinococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Flavobacterium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Carboxydothermus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Prochlorococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chloroflexus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chlamydia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhodospirillum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Acidobacterium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Nostoc
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Candidatus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bordetella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Synechococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bacillus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Acholeplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Acholeplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Opitutus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Mycoplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermodesulfovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermanaerovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhodospirillum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Aquifex
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Dictyoglomus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pirellula
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Methylacidiphilum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermobaculum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Nostoc
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chlamydia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhizobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Acholeplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Prochlorococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Fibrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhodopirellula
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Corynebacterium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bdellovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermomicrobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Dictyoglomus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermomicrobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chlamydia
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Methylacidiphilum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Deinococcus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Methylacidiphilum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermobaculum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermodesulfovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Mycoplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Dictyoglomus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pedobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermodesulfovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Carboxydothermus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Opitutus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Alicyclobacillus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Alicyclobacillus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Elusimicrobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmata
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Fibrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Mycoplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Acholeplasma
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermotoga
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Fibrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pirellula
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bdellovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bacteroides
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Shewanella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermanaerovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Opitutus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Shewanella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Aquifex
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Opitutus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhizobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Psychrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Fibrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Pirellula
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Shewanella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Campylobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bordetella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Flavobacterium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Bordetella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Rhizobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Fibrobacter
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Leptospira
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Methylacidiphilum
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Gemmatimonas
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Chlorobium
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Cupriavidus
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Coxiella
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermanaerovibrio
# The file :  ../data/training_data / bacteria_Cupriavidus_taiwanensis_isolate_Cupriavidus_taiwanensis_STM_6119_chromosome_CBM2610_a.csv  is empty.
# Thermotoga

# %%
print(listOrigins)
# Out:
# ['Bacillus', 'Candidatus', 'Bordetella', 'Cupriavidus', 'Cupriavidus', 'Rickettsia', 'Mycoplasma', 'Rickettsia', 'Cupriavidus', 'Gemmata', 'Gloeobacter', 'Gemmatimonas', 'Bacillus', 'Cupriavidus', 'Deinococcus', 'Cupriavidus', 'Pedobacter', 'Pedobacter', 'Psychrobacter', 'Rhodospirillum', 'Opitutus', 'Deinococcus', 'Rhizobium', 'Carboxydothermus', 'Chlamydia', 'Cupriavidus', 'Cupriavidus', 'Deinococcus', 'Flavobacterium', 'Carboxydothermus', 'Cupriavidus', 'Cupriavidus', 'Cupriavidus', 'Prochlorococcus', 'Gemmata', 'Cupriavidus', 'Chloroflexus', 'Chlamydia', 'Rhodospirillum', 'Acidobacterium', 'Cupriavidus', 'Cupriavidus', 'Nostoc', 'Candidatus', 'Bordetella', 'Cupriavidus', 'Synechococcus', 'Bacillus', 'Acholeplasma', 'Acholeplasma', 'Cupriavidus', 'Opitutus', 'Cupriavidus', 'Cupriavidus', 'Mycoplasma', 'Cupriavidus', 'Cupriavidus', 'Thermodesulfovibrio', 'Thermanaerovibrio', 'Rhodospirillum', 'Aquifex', 'Gemmatimonas', 'Gemmata', 'Gemmata', 'Dictyoglomus', 'Cupriavidus', 'Coxiella', 'Cupriavidus', 'Gemmata', 'Cupriavidus', 'Cupriavidus', 'Cupriavidus', 'Pirellula', 'Cupriavidus', 'Leptospira', 'Cupriavidus', 'Methylacidiphilum', 'Cupriavidus', 'Cupriavidus', 'Thermobaculum', 'Nostoc', 'Coxiella', 'Coxiella', 'Chlamydia', 'Cupriavidus', 'Rhizobium', 'Acholeplasma', 'Prochlorococcus', 'Fibrobacter', 'Cupriavidus', 'Rhodopirellula', 'Corynebacterium', 'Cupriavidus', 'Bdellovibrio', 'Cupriavidus', 'Thermomicrobium', 'Thermus', 'Dictyoglomus', 'Thermomicrobium', 'Chlamydia', 'Cupriavidus', 'Methylacidiphilum', 'Gemmata', 'Deinococcus', 'Cupriavidus', 'Cupriavidus', 'Cupriavidus', 'Cupriavidus', 'Coxiella', 'Methylacidiphilum', 'Cupriavidus', 'Cupriavidus', 'Cupriavidus', 'Gemmata', 'Thermobaculum', 'Thermodesulfovibrio', 'Mycoplasma', 'Dictyoglomus', 'Pedobacter', 'Cupriavidus', 'Thermodesulfovibrio', 'Carboxydothermus', 'Gemmata', 'Gemmatimonas', 'Opitutus', 'Alicyclobacillus', 'Cupriavidus', 'Alicyclobacillus', 'Elusimicrobium', 'Gemmata', 'Cupriavidus', 'Fibrobacter', 'Cupriavidus', 'Mycoplasma', 'Acholeplasma', 'Thermotoga', 'Fibrobacter', 'Pirellula', 'Leptospira', 'Bdellovibrio', 'Cupriavidus', 'Cupriavidus', 'Bacteroides', 'Shewanella', 'Cupriavidus', 'Leptospira', 'Leptospira', 'Thermanaerovibrio', 'Cupriavidus', 'Opitutus', 'Cupriavidus', 'Shewanella', 'Aquifex', 'Gemmatimonas', 'Opitutus', 'Leptospira', 'Rhizobium', 'Cupriavidus', 'Psychrobacter', 'Coxiella', 'Cupriavidus', 'Cupriavidus', 'Fibrobacter', 'Leptospira', 'Pirellula', 'Cupriavidus', 'Shewanella', 'Gemmatimonas', 'Cupriavidus', 'Campylobacter', 'Bordetella', 'Flavobacterium', 'Cupriavidus', 'Cupriavidus', 'Bordetella', 'Rhizobium', 'Coxiella', 'Cupriavidus', 'Cupriavidus', 'Fibrobacter', 'Leptospira', 'Methylacidiphilum', 'Gemmatimonas', 'Cupriavidus', 'Chlorobium', 'Cupriavidus', 'Cupriavidus', 'Coxiella', 'Thermanaerovibrio', 'Thermotoga']
